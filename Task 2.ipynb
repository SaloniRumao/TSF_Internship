# %% [markdown]
# # THE SPARKS FOUNDATION

# %% [markdown]
# ### GRIP : DATA SCIENCE & BUSINESS ANALYTICS INTERN - JULY 2021

# %% [markdown]
# ### Submitted by : Saloni Rumao

# %% [markdown]
# ### Task 2: Prediction using Unsupervised ML

# %% [markdown]
# ### Problem Statement: From the given ‘Iris’ dataset, predict the optimum number of clusters and represent it visually.

# %%
from IPython.display import Image
Image(filename='D:\\TSF2.PNG')

# %% [markdown]
# #### Importing required libraries

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np
from sklearn import datasets
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading data

# %%
data=pd.read_csv("C:\\Users\\saloni rumao\\Downloads\\Iris.csv")

# %% [markdown]
# ### Understanding data

# %% [markdown]
# ##### Displaying first and last 5 rows

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# Structure of data
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #### Descriptive Statistics

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Checking Missing Values

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# ##### There are no missing values.

# %%
# Dropping ID 
data=data.drop("Id",axis=1)
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ##### Dropped the 'Id' column as it is not required for further analysis.

# %%
# To see different species
data["Species"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
sns.pairplot(data,hue='Species',diag_kind='kde',palette='husl')

# %% [markdown]
#  Setosa is isolated from the other two species whereas Versicolor and Virginica mostly have similar dimensions.
#  High correlation between Petal length & Petal Width.
#  Setosa has low dimensions for all the features.
#  Versicolor has average dimensions for all the features.
#  Virginica has high dimensions for all the features.

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True,cmap='Purples')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Petal length and Petal width are highly correlated.

# %%
# Removing Species column to predict clusters
X=data.iloc[:,0:4].values

# %% [markdown]
# ###### Finding optimum number of clusters for K-means Algorithm using Elbow Method

# %%
from sklearn.cluster import KMeans

#initializing the list for the values of wcss
WCSS_values = [] # WCSS= Within Clusters Sum of Squares

#using for loop for iterations from 1 to 10. Elbow Technique
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    WCSS_values.append(kmeans.inertia_)
    
plt.plot(range(1,11),WCSS_values,color='blue', marker='o', linewidth=1, markersize=5)
plt.title("The Elbow Method Graph")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# ##### The elbow is formed at 3, so the optimum number of clusters is 3.

# %% [markdown]
# ### Model Fitting

# %%
# applying k-Means classifier to the dataset
kmeans = KMeans(n_clusters = 3, init = 'k-means++',random_state = 42)
y_pred = kmeans.fit_predict(X)   # fitting model to dataset

# %% [markdown]
# ### Visualising the clusters for Sepal length & Sepal width

# %%
plt.scatter(X[y_pred == 0 ,0] , X[y_pred == 0 ,1] , s=70 , c = 'salmon' , label = 'Setosa')
plt.scatter(X[y_pred == 1 ,0] , X[y_pred == 1 ,1] , s=70 , c = '#17becf' , label = 'Versicolour')
plt.scatter(X[y_pred == 2 ,0] , X[y_pred == 2 ,1] , s=70 , c = '#9467bd' , label = 'Virginica')

# To plot centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:,0] , kmeans.cluster_centers_[:,1] , s=100 , c = 'yellow' , label = 'Centroid')
plt.title("Optimal Clusters ")
plt.legend()
plt.show()

# %% [markdown]
# ### We have our 3 distinct clusters for Setosa, Versicolour and Virginica species of Iris flower.
